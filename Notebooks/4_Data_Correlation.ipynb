# %% [markdown]
# <a href="https://colab.research.google.com/github/luferIPCA/MIA-MLA-24-25/blob/main/4_Data_Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Masters' in Applied Artificial Intelligence
# ## Machine Learning Algorithms Course
#
# Notebooks for MLA course
#
# by [*lufer*](mailto:lufer@ipca.pt)
#
# ---
# (2025)

# %% [markdown]
# # ML Modelling - Part II
#
# **Contents**:
#
# 1.  **Data Correlation**

# %% [markdown]
# ## Environment preparation

# %% [markdown]
# ### Importing necessary Libraries

# %%
#!pip install pandas-profiling

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#from pandas_profiling import ProfileRepor   #see https://www.kaggle.com/discussions/general/233785
from scipy import stats

# %% [markdown]
# Mounting Drive

# %%
from google.colab import drive

# it will ask for your google drive credentiaals
drive.mount('/content/gDrive/', force_remount=True)
# Out:
# Mounted at /content/gDrive/

# %%
import os
print(os.getcwd())
# Out:
# /content

# %% [markdown]
# ## 1 - Correlations in Dataset

# %% [markdown]
# Essential Data Correlations  using Pandas *corr()*

# %% [markdown]
# ### **Example 1:** Heart Disease

# %% [markdown]
# *Loading dataset*

# %%
import os
#print(os.getcwd())

filePath='/content/gDrive/MyDrive/Colab Notebooks/MIAA - ML - 2025-2026/Datasets/'
ds = pd.read_csv(filePath+"heart-disease.csv")
pd.set_option("display.precision", 2)

# %%
ds.head()
#len(ds)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
#Example of correlation distribution
ax1 = ds.head().plot.scatter(x='thalach',
                      y='chol',
                      c='DarkBlue')

# %% [markdown]
# ***Correlation distribution***

# %%
#corr() calculate variables correlations
print(ds.corr())
# Answer
# Strong negative correlation example: between thal thalach
# Out:
#            age   sex    cp  trestbps  chol       fbs  restecg   thalach  \
# age       1.00 -0.10 -0.07      0.27  0.22  1.21e-01    -0.13 -3.90e-01
# sex      -0.10  1.00 -0.04     -0.08 -0.20  2.72e-02    -0.06 -4.94e-02
# cp       -0.07 -0.04  1.00      0.04 -0.08  7.93e-02     0.04  3.07e-01
# trestbps  0.27 -0.08  0.04      1.00  0.13  1.82e-01    -0.12 -3.93e-02
# chol      0.22 -0.20 -0.08      0.13  1.00  2.69e-02    -0.15 -2.18e-02
# fbs       0.12  0.03  0.08      0.18  0.03  1.00e+00    -0.10 -8.87e-03
# restecg  -0.13 -0.06  0.04     -0.12 -0.15 -1.04e-01     1.00  4.84e-02
# thalach  -0.39 -0.05  0.31     -0.04 -0.02 -8.87e-03     0.05  1.00e+00
# exang     0.09  0.14 -0.40      0.06  0.07  4.93e-02    -0.07 -3.80e-01
# oldpeak   0.21  0.08 -0.17      0.19  0.06  1.09e-02    -0.05 -3.50e-01
# slope    -0.17 -0.03  0.13     -0.12 -0.01 -6.19e-02     0.09  3.95e-01
# ca        0.27  0.11 -0.18      0.10  0.07  1.37e-01    -0.08 -2.08e-01
# thal      0.07  0.20 -0.16      0.06  0.10 -4.22e-02    -0.02 -9.81e-02
# target   -0.23 -0.28  0.43     -0.14 -0.10 -4.12e-02     0.13  4.23e-01
#
#           exang  oldpeak  slope    ca  thal  target
# age        0.09     0.21  -0.17  0.27  0.07   -0.23
# sex        0.14     0.08  -0.03  0.11  0.20   -0.28
# cp        -0.40    -0.17   0.13 -0.18 -0.16    0.43
# trestbps   0.06     0.19  -0.12  0.10  0.06   -0.14
# chol       0.07     0.06  -0.01  0.07  0.10   -0.10
# fbs        0.05     0.01  -0.06  0.14 -0.04   -0.04
# restecg   -0.07    -0.05   0.09 -0.08 -0.02    0.13
# thalach   -0.38    -0.35   0.40 -0.21 -0.10    0.42
# exang      1.00     0.31  -0.27  0.11  0.20   -0.44
# oldpeak    0.31     1.00  -0.58  0.22  0.20   -0.44
# slope     -0.27    -0.58   1.00 -0.07 -0.09    0.35
# ca         0.11     0.22  -0.07  1.00  0.15   -0.38
# thal       0.20     0.20  -0.09  0.15  1.00   -0.34
# target    -0.44    -0.44   0.35 -0.38 -0.34    1.00

# %% [markdown]
# ***Correlation Matrix with Seaborn***

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(ds.corr(),  annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ***Dataframe Correlation using Pearson r***

# %%
# To find the correlation among all columns using pearson method
ds.corr(method='pearson')
# Out:
#            age   sex    cp  trestbps  chol       fbs  restecg   thalach  \
# age       1.00 -0.10 -0.07      0.27  0.22  1.21e-01    -0.13 -3.90e-01
# sex      -0.10  1.00 -0.04     -0.08 -0.20  2.72e-02    -0.06 -4.94e-02
# cp       -0.07 -0.04  1.00      0.04 -0.08  7.93e-02     0.04  3.07e-01
# trestbps  0.27 -0.08  0.04      1.00  0.13  1.82e-01    -0.12 -3.93e-02
# chol      0.22 -0.20 -0.08      0.13  1.00  2.69e-02    -0.15 -2.18e-02
# fbs       0.12  0.03  0.08      0.18  0.03  1.00e+00    -0.10 -8.87e-03
# restecg  -0.13 -0.06  0.04     -0.12 -0.15 -1.04e-01     1.00  4.84e-02
# thalach  -0.39 -0.05  0.31     -0.04 -0.02 -8.87e-03     0.05  1.00e+00
# exang     0.09  0.14 -0.40      0.06  0.07  4.93e-02    -0.07 -3.80e-01
# oldpeak   0.21  0.08 -0.17      0.19  0.06  1.09e-02    -0.05 -3.50e-01
# slope    -0.17 -0.03  0.13     -0.12 -0.01 -6.19e-02     0.09  3.95e-01
# ca        0.27  0.11 -0.18      0.10  0.07  1.37e-01    -0.08 -2.08e-01
# thal      0.07  0.20 -0.16      0.06  0.10 -4.22e-02    -0.02 -9.81e-02
# target   -0.23 -0.28  0.43     -0.14 -0.10 -4.12e-02     0.13  4.23e-01
#
#           exang  oldpeak  slope    ca  thal  target
# age        0.09     0.21  -0.17  0.27  0.07   -0.23
# sex        0.14     0.08  -0.03  0.11  0.20   -0.28
# cp        -0.40    -0.17   0.13 -0.18 -0.16    0.43
# trestbps   0.06     0.19  -0.12  0.10  0.06   -0.14
# chol       0.07     0.06  -0.01  0.07  0.10   -0.10
# fbs        0.05     0.01  -0.06  0.14 -0.04   -0.04
# restecg   -0.07    -0.05   0.09 -0.08 -0.02    0.13
# thalach   -0.38    -0.35   0.40 -0.21 -0.10    0.42
# exang      1.00     0.31  -0.27  0.11  0.20   -0.44
# oldpeak    0.31     1.00  -0.58  0.22  0.20   -0.44
# slope     -0.27    -0.58   1.00 -0.07 -0.09    0.35
# ca         0.11     0.22  -0.07  1.00  0.15   -0.38
# thal       0.20     0.20  -0.09  0.15  1.00   -0.34
# target    -0.44    -0.44   0.35 -0.38 -0.34    1.00

# %% [markdown]
# ***Dataframe Correlation using Kendal p***

# %%
# To find the correlation among all columns using kendall method
ds.corr(method='kendall')
# Out:
#            age   sex    cp  trestbps  chol   fbs  restecg  thalach  exang  \
# age       1.00 -0.09 -0.07      0.20  0.14  0.09    -0.12    -0.27   0.06
# sex      -0.09  1.00 -0.05     -0.06 -0.13  0.03    -0.04    -0.04   0.14
# cp       -0.07 -0.05  1.00      0.02 -0.07  0.07     0.06     0.26  -0.40
# trestbps  0.20 -0.06  0.02      1.00  0.09  0.13    -0.11    -0.02   0.04
# chol      0.14 -0.13 -0.07      0.09  1.00  0.03    -0.13    -0.04   0.07
# fbs       0.09  0.03  0.07      0.13  0.03  1.00    -0.10    -0.01   0.05
# restecg  -0.12 -0.04  0.06     -0.11 -0.13 -0.10     1.00     0.08  -0.07
# thalach  -0.27 -0.04  0.26     -0.02 -0.04 -0.01     0.08     1.00  -0.33
# exang     0.06  0.14 -0.40      0.04  0.07  0.05    -0.07    -0.33   1.00
# oldpeak   0.19  0.08 -0.15      0.10  0.04  0.03    -0.06    -0.31   0.28
# slope    -0.14 -0.02  0.15     -0.07 -0.02 -0.05     0.11     0.35  -0.27
# ca        0.27  0.11 -0.19      0.07  0.09  0.13    -0.10    -0.20   0.15
# thal      0.07  0.23 -0.19      0.05  0.07 -0.01    -0.02    -0.13   0.23
# target   -0.20 -0.28  0.43     -0.10 -0.11 -0.04     0.15     0.35  -0.44
#
#           oldpeak  slope    ca  thal  target
# age          0.19  -0.14  0.27  0.07   -0.20
# sex          0.08  -0.02  0.11  0.23   -0.28
# cp          -0.15   0.15 -0.19 -0.19    0.43
# trestbps     0.10  -0.07  0.07  0.05   -0.10
# chol         0.04  -0.02  0.09  0.07   -0.11
# fbs          0.03  -0.05  0.13 -0.01   -0.04
# restecg     -0.06   0.11 -0.10 -0.02    0.15
# thalach     -0.31   0.35 -0.20 -0.13    0.35
# exang        0.28  -0.27  0.15  0.23   -0.44
# oldpeak      1.00  -0.51  0.19  0.21   -0.38
# slope       -0.51   1.00 -0.09 -0.14    0.36
# ca           0.19  -0.09  1.00  0.17   -0.43
# thal         0.21  -0.14  0.17  1.00   -0.39
# target      -0.38   0.36 -0.43 -0.39    1.00

# %% [markdown]
# ### **Example 2:** Students and Classes

# %% [markdown]
# *Loading dataset*

# %%
# students and Classes
df = {
    "Faltas": [8, 2, 5, 12, 15, 9, 6],
    "Nota": [78,92,90,58,43,74,81]
}

data = pd.DataFrame(df)

ax1 = data.plot.scatter(x='Faltas',
                      y='Nota',
                      c='DarkBlue')

# %% [markdown]
# ***Correlation distribution***

# %%
# Calculate the Pearson correlation
correlation = data["Faltas"].corr(data["Nota"])
print(f"Pearson Correlation: {correlation}")
# Out:
# Pearson Correlation: -0.9747632142351275

# %%
#corr() calculate variables correlations using Person method, by default!
print(data.corr())
# Answer
# Strong negative correlation
# Out:
#         Faltas  Nota
# Faltas    1.00 -0.97
# Nota     -0.97  1.00

# %%
# Calculate the Kendall correlation
kendall_correlation = data["Faltas"].corr(data["Nota"], method='kendall')
print(f"Kendall Correlation: {kendall_correlation}")
# Out:
# Kendall Correlation: -1.0

# %%
# Calculate the Spearman correlation
spearman_correlation = data["Faltas"].corr(data["Nota"], method='spearman')
print(f"Spearman Correlation: {spearman_correlation}")
# Out:
# Spearman Correlation: -1.0

# %% [markdown]
# ***Visualizing correlations with Seaborn***

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(data.corr().abs(),  annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### **Example 3:** - Games and Points

# %% [markdown]
# *Loading dataset*

# %%
# students and Classes
df = {
    "Jogos": [1, 2, 3, 4, 5, 6],
    "Pontos": [42,131,219,308,396,485]
}

data = pd.DataFrame(df)

ax1 = data.plot.scatter(x='Jogos',
                      y='Pontos',
                      c='DarkBlue')

# %% [markdown]
# ***Using Seaborn Heatmap***

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(data.corr(),  annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ***Persons r Using Correlation Matrix***

# %%
#corr() calculate variables correlations
correlation_pearson = data.corr()
correlation_pearson
# Answer
# Strong positive correlation
# Out:
#         Jogos  Pontos
# Jogos     1.0     1.0
# Pontos    1.0     1.0

# %% [markdown]
# ***Spearman t Correlation***

# %%
# Calcula a correlação de Spearman
correlation_spearman = data.corr(method='spearman')
correlation_spearman
# Out:
#         Jogos  Pontos
# Jogos     1.0     1.0
# Pontos    1.0     1.0

# %% [markdown]
# ### ***Example 4: - Boston House***
#
# See [Boston House Dataset](https://www.kaggle.com/code/prasadperera/the-boston-housing-dataset)

# %%
ds2 = pd.read_csv(filePath+"BostonHousing.csv")
pd.set_option("display.precision", 2)

# %%
ds2.head()

# %%
# how many numerical features
ds2.select_dtypes(include=np.number).columns
#answer
#none! all features are numerical
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
ds2.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object

# %%
#select only the numeric columns in the DataFrame
ds2.select_dtypes(include=np.number)
# Out:
#          crim    zn  indus  chas   nox    rm   age   dis  rad  tax  ptratio  \
# 0    6.32e-03  18.0   2.31     0  0.54  6.58  65.2  4.09    1  296     15.3
# 1    2.73e-02   0.0   7.07     0  0.47  6.42  78.9  4.97    2  242     17.8
# 2    2.73e-02   0.0   7.07     0  0.47  7.18  61.1  4.97    2  242     17.8
# 3    3.24e-02   0.0   2.18     0  0.46  7.00  45.8  6.06    3  222     18.7
# 4    6.91e-02   0.0   2.18     0  0.46  7.15  54.2  6.06    3  222     18.7
# ..        ...   ...    ...   ...   ...   ...   ...   ...  ...  ...      ...
# 501  6.26e-02   0.0  11.93     0  0.57  6.59  69.1  2.48    1  273     21.0
# 502  4.53e-02   0.0  11.93     0  0.57  6.12  76.7  2.29    1  273     21.0
# 503  6.08e-02   0.0  11.93     0  0.57  6.98  91.0  2.17    1  273     21.0
# 504  1.10e-01   0.0  11.93     0  0.57  6.79  89.3  2.39    1  273     21.0
# 505  4.74e-02   0.0  11.93     0  0.57  6.03  80.8  2.50    1  273     21.0
#
#           b  lstat  medv
# 0    396.90   4.98  24.0
# 1    396.90   9.14  21.6
# 2    392.83   4.03  34.7
# 3    394.63   2.94  33.4
# 4    396.90   5.33  36.2
# ..      ...    ...   ...
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
#check features types
# Checking values
result = ds2.applymap(np.isreal)

# Display result
print("Result:\n",result)
#true means numerical
#false means non numerical

# %% [markdown]
# Correlation Matrix

# %%
#get correlations
plt.figure(figsize=(20, 10))
sns.heatmap(ds2.corr(),  annot=True)
# Out:
# <Axes: >

# %% [markdown]
# *   “tax” and “rad” columns are highly correlated with a value of 0.92 (positive correlation).
# *   The columns LSTAT, INDUS, RM, TAX, NOX, PTRAIO has a correlation score above 0.5 with MEDV which is a good indication of using as predictors

# %% [markdown]
# ### **Filtering out self-correlations**
#
# Self-correlations are always 1, thus it can be ignored!

# %%
import pandas as pd

# Extend the DataFrame with new features
data = {
    "Faltas": [8, 2, 5, 12, 15, 9, 6],
    "Nota": [78, 92, 90, 58, 43, 74, 81],
    "Estudo": [10, 25, 20, 5, 3, 15, 18],
    "Participação": [80, 95, 90, 50, 40, 75, 85]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Faltas  Nota  Estudo  Participação
# 0       8    78      10            80
# 1       2    92      25            95
# 2       5    90      20            90
# 3      12    58       5            50
# 4      15    43       3            40
# 5       9    74      15            75
# 6       6    81      18            85

# %% [markdown]
# Compute the Correlation Matrix

# %%
# Calculate the correlation matrix
correlation_matrix = df.corr()

print("Correlation Matrix:")
correlation_matrix
# Out:
# Correlation Matrix:
#               Faltas  Nota  Estudo  Participação
# Faltas          1.00 -0.97   -0.96         -0.97
# Nota           -0.97  1.00    0.93          0.99
# Estudo         -0.96  0.93    1.00          0.93
# Participação   -0.97  0.99    0.93          1.00

# %%
#Filtering Out Self-Correlations
# Unstack the correlation matrix
corr_pairs = correlation_matrix.unstack()

# Filter out self-correlations (where feature pairs are the same)
filtered_corr_pairs = corr_pairs[corr_pairs.index.get_level_values(0) != corr_pairs.index.get_level_values(1)]

# Sort the remaining pairs in descending order of correlation
filtered_corr_pairs = filtered_corr_pairs.sort_values(kind="quicksort", ascending=True)

print(filtered_corr_pairs)
# Out:
# Faltas        Nota           -0.97
# Nota          Faltas         -0.97
# Faltas        Participação   -0.97
# Participação  Faltas         -0.97
# Estudo        Faltas         -0.96
# Faltas        Estudo         -0.96
# Estudo        Nota            0.93
# Nota          Estudo          0.93
# Participação  Estudo          0.93
# Estudo        Participação    0.93
# Nota          Participação    0.99
# Participação  Nota            0.99
# dtype: float64

# %%
corr_pairs.index.duplicated()
#there is no repeated index
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False])

# %%
#Explanation: what does means?
#corr_pairs[corr_pairs.index.get_level_values(0) != corr_pairs.index.get_level_values(1)]

#analyse separately
#corr_pairs
#corr_pairs.index
#print(type(corr_pairs.index))
#corr_pairs.index.get_level_values(0)

#get_level_values(0) and get_level_values(1):
#These retrieve the first and second elements of the multi-level index of the Series created by unstack().

# %% [markdown]
# End!

# %% [markdown]
# ## 2 - Selecting Features
#
# What feature can be "excluded" for the training process?
# Whar are irrelevant features

# %%
import pandas as pd

# Extend the DataFrame with new features
data = {
    "Faltas": [8, 2, 5, 12, 15, 9, 6],
    "Nota": [78, 92, 90, 58, 43, 74, 81],
    "Estudo": [10, 25, 20, 5, 3, 15, 18],
    "Participação": [80, 95, 90, 50, 40, 75, 85]
}

df = pd.DataFrame(data)
print(df)

# %% [markdown]
# Compute the Correlation Matrix

# %%
# Calculate the correlation matrix
correlation_matrix = df.corr()

print("Correlation Matrix:")
correlation_matrix

# %% [markdown]
#  Select Feature to Exclude
#  * Suppose *Nota* as the target variable
#
#  * Look for features with weak correlations with the target variable or high correlations with other features (redundancy).
#
# * Visualize the correlations using a heatmap (with libraries like seaborn - optional).

# %% [markdown]
# ### Look for weak correlations

# %%
#correlation between Nota and the others features
correlation_matrix['Nota']
#interpret it!

#extremely strong positive bewtween Nota and Study. What that means?
#Extremely strong positive bewtween Nota and Participation. What that means?
#Extremely strong negative bewtween Nota and Faltas. What that means?

# %%
correlation_matrix["Nota"].idxmin()

# %%
# Find the feature with the weakest correlation with 'Nota'
correlations_with_nota = correlation_matrix["Nota"].drop("Nota")
feature_to_exclude = correlations_with_nota.idxmin()

print(f"The feature to exclude is: {feature_to_exclude}")

# %% [markdown]
# ### Visualizing

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(correlation_matrix, annot=True)
#what it does?
#sns.heatmap(correlation_matrix, annot=True,cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# **Exclude the selected feature**

# %%
# Drop the feature from the DataFrame
df_reduced = df.drop(columns=[feature_to_exclude])
#or
#df_reduced = df.drop(feature_to_exclude,axis=1)
print(df_reduced)

# %% [markdown]
# ### **Another approach**

# %%
# Plot the heatmap of the correlation matrix
sns.heatmap(correlation_matrix, annot=True,cmap='coolwarm')
plt.show()

#corr_pairs = correlation_matrix.abs().unstack().sort_values(kind="quicksort", ascending=False)
#unstack(): pass 2D (matrix) for 1D serie, i.e, series of pairs of features
corr_pairs = correlation_matrix.unstack().sort_values(kind="quicksort", ascending=True)  #or mergesort; heapsort

# Identify highly correlated pairs (example: more than 80%)
threshold = 0.8
high_corr = [(a, b) for a, b in corr_pairs.index if a != b and corr_pairs[(a, b)] > threshold]

# %%
corr_pairs

# %%
high_corr

# %%
corr_pairs.index
#print(type(corr_pairs.index))
#index is a pair of strings, in this case!
